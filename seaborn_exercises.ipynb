# %% [markdown]
# # Seaborn

# %% [markdown]
# Seaborn is a Python data visualization library that is built on top of Matplotlib. It can create statistical graphics in a simple and concise manner.

# %%
#importing libraries,for data visualizations,data analysis, and conduct statistical tests in Python. 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Use seaborn's load_dataset function to load the iris database to answer the following questions:

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
1. What does the distribution of petal lengths look like?

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# kde=True argument approximates the distribution for continuous values.

sns.histplot(iris.petal_length, kde=True)
plt.show()

# %%
sns.displot(data = iris, x='petal_length', kde=True)
plt.show()

# %% [markdown]
# #### sns.histplot and sns.displot are very similar. The primary differences are contained in the kwargs for each visual.

# %% [markdown]
# #### 2. Is there a relationship between petal length and petal width?

# %%
It appears that (in general) the longer the petal, the wider the petal.

# %%
#visual length and width of petals together including the species
sns.relplot(x='petal_length', y='petal_width', hue = 'species', data=iris)
plt.title("Petal length vs Petal width")
# Out:
# Text(0.5, 1.0, 'Petal length vs Petal width')

# %%
#visual length and width of petals together
sns.scatterplot(data = iris, x='petal_length', y='petal_width', color='m')
plt.show()

# %%
The above two scatterplots are very similar. The primary differences are contained in the kwargs for each visual.

# %% [markdown]
# #### 3.Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column?

# %% [markdown]
#  May be able to predict 'setosa' based on sepal size. Setosa (blue) have shorter sepal lengths/ are wider.
#  Versicolor (orange) and Virginic (green) are too similar.

# %%
#using relplot
sns.relplot(x='sepal_width', y='sepal_length', hue="species", data=iris)

# %%
# Using scatter plot
sns.scatterplot(data = iris, x='sepal_width',y='sepal_length', hue= 'species')
plt.show()

# %%
#Changing the individual points of a relplot into a line
#This will make it easier to visualize differences in species
sns.relplot(data = iris, x='sepal_width', y='sepal_length', hue ='species', kind='line')
plt.show()

# %% [markdown]
# sns.relplot and sns.scatterplot are very similar. The primary differences are contained in the kwargs for each visual.

# %%
4.Which features would be best used to predict species?

# %%
Petal length features would be best used to predict species.

# %%
#create a pairplot to see all features
sns.pairplot(data=iris, corner=True, hue='species')
plt.show()

# %%
#group by species and see if there is a wide range between petal lengths
#this gives average petal length

iris.groupby('species').petal_length.agg('mean')
# Out:
# species
# setosa        1.462
# versicolor    4.260
# virginica     5.552
# Name: petal_length, dtype: float64

# %%
iris.groupby('species').petal_width.agg('mean')
# Out:
# species
# setosa        0.246
# versicolor    1.326
# virginica     2.026
# Name: petal_width, dtype: float64

# %%
iris.groupby('species').sepal_length.agg('mean')
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %%
iris.groupby('species').sepal_width.agg('mean')
# Out:
# species
# setosa        3.428
# versicolor    2.770
# virginica     2.974
# Name: sepal_width, dtype: float64

# %% [markdown]
# #### The average petal length for each species appears to have the largest variation among species, compared to the other features. This could mean that petal_length would be a good indictor of the species we are dealing with.

# %% [markdown]
# Part II

# %% [markdown]
# ### 1.a. Load the anscombe dataset from seaborn. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?

# %%
Answer:
in ' x' : Noticed that the only dataset that is different is dataset I
in 'y': dataset III and IV are very similar

# %%
from pydataset import data

#Load the anscombe dataset using seaborn
anscombe = sns.load_dataset('anscombe')
anscombe.dtypes
# Out:
# dataset     object
# x          float64
# y          float64
# dtype: object

# %%
#looking at data
anscombe.sample(30)
# Out:
#    dataset     x      y
# 41      IV   8.0   5.56
# 21      II   5.0   4.74
# 15      II  11.0   9.26
# 19      II  12.0   9.13
# 31     III   7.0   6.42
# 37      IV   8.0   8.47
# 7        I   4.0   4.26
# 27     III  14.0   8.84
# 4        I  11.0   8.33
# 18      II   4.0   3.10
# 3        I   9.0   8.81
# 30     III  12.0   8.15
# 11      II  10.0   9.14
# 32     III   5.0   5.73
# 36      IV   8.0   8.84
# 24     III  13.0  12.74
# 0        I  10.0   8.04
# 20      II   7.0   7.26
# 12      II   8.0   8.14
# 17      II   6.0   6.13
# 43      IV   8.0   6.89
# 26     III  11.0   7.81
# 35      IV   8.0   7.71
# 29     III   4.0   5.39
# 5        I  14.0   9.96
# 10       I   5.0   5.68
# 42      IV   8.0   7.91
# 14      II   9.0   8.77
# 13      II  13.0   8.74
# 2        I  13.0   7.58

# %%
#checking datatypes
anscombe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
#how many of each dataset do we have
anscombe.dataset.value_counts()
# Out:
# dataset
# I      11
# II     11
# III    11
# IV     11
# Name: count, dtype: int64

# %%
#let's group the datasets together then get stats on them
anscombe.groupby('dataset').describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %% [markdown]
# ### 1.b. Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
#each unique dataset label in the 'dataset' column will be represented in a separate column of plots
sns.relplot(data=anscombe, x='x', y='y', col='dataset', col_wrap= 2)

# %% [markdown]
# ##### Although the descriptive statistics appear to be very similar among all four datasets, the visuals are different. This indicates that stats and visuals must be reviewed together or only part of the story will be told.

# %% [markdown]
# ### 2.Load the InsectSprays dataset from pydataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
from pydataset import data

insect_sprays = data('InsectSprays')
insect_sprays.head()
# Out:
#    count spray
# 1     10     A
# 2      7     A
# 3     20     A
# 4     14     A
# 5     14     A

# %%
insect_sprays.dtypes
# Out:
# count     int64
# spray    object
# dtype: object

# %%
insect_sprays.spray.nunique()
# Out:
# 6

# %%
#let's look at what this dataframe holds
data('InsectSprays', show_doc = True)
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
#     summary(fm1)
#     opar <- par(mfrow = c(2, 2), oma = c(0, 0, 1.1, 0))
#     plot(fm1)
#     fm2 <- aov(sqrt(count) ~ spray, data = InsectSprays)
#     summary(fm2)
#     plot(fm2)
#     par(opar)

# %%
#look at the data
insect_sprays.sample(20)
# Out:
#     count spray
# 10     20     A
# 69     26     F
# 57      3     E
# 71     24     F
# 36      4     C
# 72     13     F
# 61     11     F
# 43      5     D
# 48      4     D
# 27      7     C
# 39     12     D
# 4      14     A
# 29      3     C
# 68     10     F
# 41      4     D
# 16     11     B
# 8      23     A
# 2       7     A
# 34      0     C
# 50      5     E

# %%
#see how many of each spray type there are
insect_sprays.spray.value_counts()
# Out:
# spray
# A    12
# B    12
# C    12
# D    12
# E    12
# F    12
# Name: count, dtype: int64

# %%
#get the count (of kills) per spray type
insect_sprays.groupby('spray').agg('sum')
# Out:
#        count
# spray
# A        174
# B        184
# C         25
# D         59
# E         42
# F        200

# %%
sns.boxplot(data=insect_sprays, y='spray', x='count')  
plt.title('Effectiveness of Different Insect Sprays')
plt.xlabel('Number of Insects killed')
plt.ylabel('Insect Sprays')
plt.show()

# %% [markdown]
# ##### Spray type F appears to have the highest insect kill count.
# ##### It appears that Spray type C is the least effective.

# %% [markdown]
# ### 3.Load the swiss dataset from pydataset and read it's documentation. Create visualizations to answer the following questions:
#
# ### Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)
# ### Does whether or not a province is Catholic influence fertility?
# ### What measure correlates most strongly with fertility?

# %%
from pydataset import data

#load the swiss data using pydataset
swiss = data('swiss')

# %%
#see what information is within that dataset
data('swiss', show_doc=True)
# Out:
# swiss
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Swiss Fertility and Socioeconomic Indicators (1888) Data
#
# ### Description
#
# Standardized fertility measure and socio-economic indicators for each of 47
# French-speaking provinces of Switzerland at about 1888.
#
# ### Usage
#
#     data(swiss)
#
# ### Format
#
# A data frame with 47 observations on 6 variables, each of which is in percent,
# i.e., in [0,100].
#
# [,1] Fertility Ig, "common standardized fertility measure" [,2] Agriculture
# [,3] Examination nation [,4] Education [,5] Catholic [,6] Infant.Mortality
# live births who live less than 1 year.
#
# All variables but 'Fert' give proportions of the population.
#
# ### Source
#
# Project "16P5", pages 549-551 in
#
# Mosteller, F. and Tukey, J. W. (1977) “Data Analysis and Regression: A Second
# Course in Statistics”. Addison-Wesley, Reading Mass.
#
# indicating their source as "Data used by permission of Franice van de Walle.
# Office of Population Research, Princeton University, 1976\. Unpublished data
# assembled under NICHD contract number No 1-HD-O-2077."
#
# ### References
#
# Becker, R. A., Chambers, J. M. and Wilks, A. R. (1988) “The New S Language”.
# Wadsworth & Brooks/Cole.

# %%
#take a look at the data
swiss.sample(10)
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Delemont           83.1         45.1            6          9     84.84
# Lavaux             65.1         73.0           19          9      2.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Boudry             70.4         38.4           26         12      5.62
# Moudon             65.0         55.1           14          3      4.52
# Sion               79.3         63.1           13         13     96.83
# Veveyse            87.1         64.5           14          6     98.61
# Lausanne           55.7         19.4           26         28     12.11
# Entremont          69.3         84.9            7          6     99.68
# ValdeTravers       67.6         18.7           25          7      8.65
#
#               Infant.Mortality
# Delemont                  22.2
# Lavaux                    20.0
# Franches-Mnt              20.2
# Boudry                    20.3
# Moudon                    22.4
# Sion                      18.1
# Veveyse                   24.5
# Lausanne                  20.2
# Entremont                 19.8
# ValdeTravers              19.5

# %%
swiss.dtypes
# Out:
# Fertility           float64
# Agriculture         float64
# Examination           int64
# Education             int64
# Catholic            float64
# Infant.Mortality    float64
# dtype: object

# %%
swiss.Catholic.nunique()
# Out:
# 46

# %% [markdown]
# ### 3a. Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

# %%
#chose cutoff point of 50% for is_catholic
#create a column where True if the percent of catholic is above 50%
swiss['is_catholic'] = swiss['Catholic'] >50 

#take a look
swiss.sample(10)
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Glane              92.4         67.8           14          8     97.16
# Cossonay           61.7         69.3           22          5      2.82
# Franches-Mnt       92.5         39.7            5          5     93.40
# Sion               79.3         63.1           13         13     96.83
# Sierre             92.2         84.6            3          3     99.46
# Morges             65.5         59.8           22         10      5.23
# Herens             77.3         89.7            5          2    100.00
# Rive Gauche        42.8         27.7           22         29     58.33
# Delemont           83.1         45.1            6          9     84.84
# La Vallee          54.3         15.2           31         20      2.15
#
#               Infant.Mortality  is_catholic
# Glane                     24.9         True
# Cossonay                  18.7        False
# Franches-Mnt              20.2         True
# Sion                      18.1         True
# Sierre                    16.3         True
# Morges                    18.0        False
# Herens                    18.3         True
# Rive Gauche               19.3         True
# Delemont                  22.2         True
# La Vallee                 10.8        False

# %%
#or
catholic_bool = lambda x: x > 50
swiss['is_catholic'] = swiss.Catholic.apply(catholic_bool)
swiss.head(5)
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Delemont                  22.2         True
# Franches-Mnt              20.2         True
# Moutier                   20.3        False
# Neuveville                20.6        False

# %% [markdown]
# ### 3b. Does whether or not a province is Catholic influence fertility?

# %%
#what is the average rate of Fertility among catholic vs non-catholic
swiss.groupby('is_catholic').Fertility.agg('mean')
# Out:
# is_catholic
# False    66.220690
# True     76.461111
# Name: Fertility, dtype: float64

# %%
#here we are plotting catholic vs non-catholic fertility rates
sns.relplot(data = swiss, x= 'Catholic', y= 'Fertility', hue = 'is_catholic')
plt.show()

# %%
#create the visual of catholic vs non-catholic fertility rates
sns.boxplot(data = swiss, x= 'is_catholic', y= 'Fertility')
plt.show()

# %% [markdown]
# ##### It appears that provinces that have primarily Catholic population do have a higher fertility rate.
# ##### Average fertility rate for Non-Catholic is 66.22 while Catholic is 76.46.

# %% [markdown]
# ### 3c. What measure correlates most strongly with fertility?

# %%
Answer: education (negative correlation)

# %%
#take a look at the numeric correlation between all features
swiss.corr()
# Out:
#                   Fertility  Agriculture  Examination  Education  Catholic  \
# Fertility          1.000000     0.353079    -0.645883  -0.663789  0.463685
# Agriculture        0.353079     1.000000    -0.686542  -0.639523  0.401095
# Examination       -0.645883    -0.686542     1.000000   0.698415 -0.572742
# Education         -0.663789    -0.639523     0.698415   1.000000 -0.153859
# Catholic           0.463685     0.401095    -0.572742  -0.153859  1.000000
# Infant.Mortality   0.416556    -0.060859    -0.114022  -0.099322  0.175496
# is_catholic        0.402813     0.410503    -0.597861  -0.154677  0.961723
#
#                   Infant.Mortality  is_catholic
# Fertility                 0.416556     0.402813
# Agriculture              -0.060859     0.410503
# Examination              -0.114022    -0.597861
# Education                -0.099322    -0.154677
# Catholic                  0.175496     0.961723
# Infant.Mortality          1.000000     0.166081
# is_catholic               0.166081     1.000000

# %%
#we can create a heatmap of this correlation
sns.heatmap(swiss.corr(), annot=True, cmap='Blues')
plt.show()

# %%
#we can create a for loop to see Fertility
for col in swiss:
    print(col)
    sns.scatterplot(data=swiss, y='Fertility', x=col)
    plt.show()
# Out:
# Fertility
# Agriculture
# Examination
# Education
# Catholic
# Infant.Mortality
# is_catholic

# %%
#the more educated someone is the less fertile they are
sns.relplot(data= swiss, x='Fertility', y='Education')

# %% [markdown]
# ##### Education appears to be most highly correlated with Fertility. There appears to be a strong negative correlation between the two features.

# %% [markdown]
# ### 4.Load the chipotle dataset from SQL, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
from env import host, user, password
url = (f'mysql+pymysql://{user}:{password}@{host}/chipotle')

# %%
chipotle = pd.read_sql('SELECT * FROM orders', url)
chipotle.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
poplr_items = chipotle.groupby('item_name').quantity.agg('sum')
poplr_items.sort_values(ascending=False)
# Out:
# item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# Chips and Tomatillo Red Chili Salsa       50
# Chicken Crispy Tacos                      50
# Chips and Tomatillo Green Chili Salsa     45
# Carnitas Soft Tacos                       40
# Steak Crispy Tacos                        36
# Chips and Tomatillo-Green Chili Salsa     33
# Steak Salad Bowl                          31
# Nantucket Nectar                          29
# Chips and Tomatillo-Red Chili Salsa       25
# Barbacoa Soft Tacos                       25
# Chips and Roasted Chili Corn Salsa        23
# Izze                                      20
# Veggie Salad Bowl                         18
# Chips and Roasted Chili-Corn Salsa        18
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Chicken Salad                              9
# Carnitas Crispy Tacos                      8
# Veggie Soft Tacos                          8
# Burrito                                    6
# Veggie Salad                               6
# Carnitas Salad Bowl                        6
# Bowl                                       4
# Steak Salad                                4
# Salad                                      2
# Crispy Tacos                               2
# Chips and Mild Fresh Tomato Salsa          1
# Carnitas Salad                             1
# Veggie Crispy Tacos                        1
# Name: quantity, dtype: int64

# %%
#check the dtypes
chipotle.dtypes
# Out:
# id                     int64
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
#remove special characters and change datatypes
chipotle.item_price = chipotle.item_price.str.strip('$').astype(float)

# %%
#finding top four items by quantity sold
top_4 = chipotle.groupby('item_name').quantity.sum().nlargest(4)
top_4
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Name: quantity, dtype: int64

# %%
#another way to do this using sort values
top_four= chipotle.groupby('item_name').quantity.agg(['sum']).sort_values(by='sum', ascending = False).head(4)
top_four
# Out:
#                      sum
# item_name
# Chicken Bowl         761
# Chicken Burrito      591
# Chips and Guacamole  506
# Steak Burrito        386

# %%
#get all the total prices per item name
all_prices = chipotle.groupby('item_name').item_price.sum()

#take a look
all_prices.head()
# Out:
# item_name
# 6 Pack Soft Drink        356.95
# Barbacoa Bowl            672.36
# Barbacoa Burrito         894.75
# Barbacoa Crispy Tacos    120.21
# Barbacoa Salad Bowl      106.40
# Name: item_price, dtype: float64

# %%
merged_df = pd.merge(top_4, all_prices, on='item_name', how='inner')
merged_df = merged_df.reset_index()
merged_df
# Out:
#              item_name  quantity  item_price
# 0         Chicken Bowl       761     7342.73
# 1      Chicken Burrito       591     5575.82
# 2  Chips and Guacamole       506     2201.04
# 3        Steak Burrito       386     3851.43

# %%
#create the plot
sns.barplot(data= merged_df, y='item_name', x='item_price')

#add title and label
plt.title('Most Popular Chipotle Items')
plt.xlabel('revenue generated')
plt.show()

# %% [markdown]
# ##### Chicken bowls have the highest revenue, followed by Chicken Burrito, Chips & Guac, and Steak Burritos.

# %% [markdown]
# ### 5.Load the sleepstudy dataset from pydataset and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
from pydataset import data

#load sleepstudy data using pydataset
sleepstudy = data('sleepstudy')
sleepstudy.head()
# Out:
#    Reaction  Days  Subject
# 1  249.5600     0      308
# 2  258.7047     1      308
# 3  250.8006     2      308
# 4  321.4398     3      308
# 5  356.8519     4      308

# %%
#take a look at the doc
data('sleepstudy', show_doc = True)
# Out:
# sleepstudy
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Reaction times in a sleep deprivation study
#
# ### Description
#
# The average reaction time per day for subjects in a sleep deprivation study.
# On day 0 the subjects had their normal amount of sleep. Starting that night
# they were restricted to 3 hours of sleep per night. The observations represent
# the average reaction time on a series of tests given each day to each subject.
#
# ### Format
#
# A data frame with 180 observations on the following 3 variables.
#
# `Reaction`
#
# Average reaction time (ms)
#
# `Days`
#
# Number of days of sleep deprivation
#
# `Subject`
#
# Subject number on which the observation was made.
#
# ### Details
#
# These data are from the study described in Belenky et al. (2003), for the
# sleep-deprived group and for the first 10 days of the study, up to the
# recovery period.
#
# ### References
#
# Gregory Belenky, Nancy J. Wesensten, David R. Thorne, Maria L. Thomas, Helen
# C. Sing, Daniel P. Redmond, Michael B. Russo and Thomas J. Balkin (2003)
# Patterns of performance degradation and restoration during sleep restriction
# and subsequent recovery: a sleep dose-response study. _Journal of Sleep
# Research_ **12**, 1–12.
#
# ### Examples
#
#     str(sleepstudy)
#     require(lattice)
#     xyplot(Reaction ~ Days | Subject, sleepstudy, type = c("g","p","r"),
#            index = function(x,y) coef(lm(y ~ x))[1],
#            xlab = "Days of sleep deprivation",
#            ylab = "Average reaction time (ms)", aspect = "xy")
#     (fm1 <- lmer(Reaction ~ Days + (Days|Subject), sleepstudy))
#     (fm2 <- lmer(Reaction ~ Days + (1|Subject) + (0+Days|Subject), sleepstudy))

# %%
sleepstudy.sample(10)
# Out:
#      Reaction  Days  Subject
# 56   309.9976     5      332
# 158  347.5855     7      370
# 97   404.2601     6      337
# 9    430.5853     8      308
# 22   194.3322     1      310
# 121  250.5265     0      351
# 87   245.4523     6      335
# 89   235.7541     8      335
# 145  314.8222     4      369
# 118  362.9184     7      350

# %%
sleepstudy.dtypes
# Out:
# Reaction    float64
# Days          int64
# Subject       int64
# dtype: object

# %%
sleepstudy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 180 entries, 1 to 180
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Reaction  180 non-null    float64
#  1   Days      180 non-null    int64
#  2   Subject   180 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 5.6 KB

# %%
sleepstudy.Reaction.nunique()
# Out:
# 180

# %%
avg_sleep = pd.DataFrame(sleepstudy.groupby('Days').Reaction.agg('mean'))
plt.plot(avg_sleep.index, avg_sleep.Reaction, linewidth=5)

# %%
#determine figure size
plt.figure(figsize=(12,8))

#create the visual for subjects
sns.lineplot(data= sleepstudy, x= 'Days', y= 'Reaction', hue= 'Subject', legend =all)

#create the visual for mean reaction time
sns.lineplot(data = sleepstudy, x = 'Days', y = 'Reaction', color = 'purple', linewidth = 7, estimator = 'mean')
# Out:
# <Axes: xlabel='Days', ylabel='Reaction'>
